# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "./stocks/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("D:/Python for Finance/Wilshire-5000-Stocks.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  A
# ./stocks/A.csv  Saved
# Finished
# Get Data for :  AA
# ./stocks/AA.csv  Saved
# Finished
# Get Data for :  AAL
# ./stocks/AAL.csv  Saved
# Finished
# Get Data for :  AAME
# ./stocks/AAME.csv  Saved
# Finished
# Get Data for :  AAN
# ./stocks/AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# ./stocks/AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# ./stocks/AAON.csv  Saved
# Finished
# Get Data for :  AAP
# ./stocks/AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# ./stocks/AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# ./stocks/AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# ./stocks/AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# ./stocks/AAXN.csv  Saved
# Finished
# Get Data for :  ABBV
# ./stocks/ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# ./stocks/ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# ./stocks/ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# ./stocks/ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# ./stocks/ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# ./stocks/ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# ./stocks/ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# ./stocks/ABMD.csv  Saved
# Finished
# Get Data for :  ABR
# ./stocks/ABR.csv  Saved
# Finished
# Get Data for :  ABT
# ./stocks/ABT.csv  Saved
# Finished
# Get Data for :  ABTX
# ./stocks/ABTX.csv  Saved
# Finished
# Get Data for :  AC
# ./stocks/AC.csv  Saved
# Finished
# Get Data for :  ACA
# ./stocks/ACA.csv  Saved
# Finished
# Get Data for :  ACAD
# ./stocks/ACAD.csv  Saved
# Finished
# Get Data for :  ACBI
# ./stocks/ACBI.csv  Saved
# Finished
# Get Data for :  ACC
# ./stocks/ACC.csv  Saved
# Finished
# Get Data for :  ACCO
# ./stocks/ACCO.csv  Saved
# Finished
# Get Data for :  ACER
# ./stocks/ACER.csv  Saved
# Finished
# Get Data for :  ACGL
# ./stocks/ACGL.csv  Saved
# Finished
# Get Data for :  ACHC
# ./stocks/ACHC.csv  Saved
# Finished
# Get Data for :  ACHV
# ./stocks/ACHV.csv  Saved
# Finished
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# ./stocks/ACIA.csv  Saved
# Finished
# Get Data for :  ACIW
# ./stocks/ACIW.csv  Saved
# Finished
# Get Data for :  ACLS
# ./stocks/ACLS.csv  Saved
# Finished
# Get Data for :  ACM
# ./stocks/ACM.csv  Saved
# Finished
# Get Data for :  ACMR
# ./stocks/ACMR.csv  Saved
# Finished
# Get Data for :  ACN
# ./stocks/ACN.csv  Saved
# Finished
# Get Data for :  ACNB
# ./stocks/ACNB.csv  Saved
# Finished
# Get Data for :  ACOR
# ./stocks/ACOR.csv  Saved
# Finished
# Get Data for :  ACRE
# ./stocks/ACRE.csv  Saved
# Finished
# Get Data for :  ACRS
# ./stocks/ACRS.csv  Saved
# Finished
# Get Data for :  ACRX
# ./stocks/ACRX.csv  Saved
# Finished
# Get Data for :  ACTG
# ./stocks/ACTG.csv  Saved
# Finished
# Get Data for :  ACU
# ./stocks/ACU.csv  Saved
# Finished
# Get Data for :  ACY
# ./stocks/ACY.csv  Saved
# Finished
# Get Data for :  ADBE
# ./stocks/ADBE.csv  Saved
# Finished
# Get Data for :  ADC
# ./stocks/ADC.csv  Saved
# Finished
# Get Data for :  ADES
# ./stocks/ADES.csv  Saved
# Finished
# Get Data for :  ADI
# ./stocks/ADI.csv  Saved
# Finished
# Get Data for :  ADM
# ./stocks/ADM.csv  Saved
# Finished
# Get Data for :  ADMA
# ./stocks/ADMA.csv  Saved
# Finished
# Get Data for :  ADMP
# ./stocks/ADMP.csv  Saved
# Finished
# Get Data for :  ADMS
# ./stocks/ADMS.csv  Saved
# Finished
# Get Data for :  ADNT
# ./stocks/ADNT.csv  Saved
# Finished
# Get Data for :  ADP
# ./stocks/ADP.csv  Saved
# Finished
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# ./stocks/ADRO.csv  Saved
# Finished
# Get Data for :  ADS
# ./stocks/ADS.csv  Saved
# Finished
# Get Data for :  ADSK
# ./stocks/ADSK.csv  Saved
# Finished
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# ./stocks/ADSW.csv  Saved
# Finished
# Get Data for :  ADT
# ./stocks/ADT.csv  Saved
# Finished
# Get Data for :  ADTN
# ./stocks/ADTN.csv  Saved
# Finished
# Get Data for :  ADUS
# ./stocks/ADUS.csv  Saved
# Finished
# Get Data for :  ADVM
# ./stocks/ADVM.csv  Saved
# Finished
# Get Data for :  ADXS
# ./stocks/ADXS.csv  Saved
# Finished
# Get Data for :  AE
# ./stocks/AE.csv  Saved
# Finished
# Get Data for :  AEE
# ./stocks/AEE.csv  Saved
# Finished
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# ./stocks/AEGN.csv  Saved
# Finished
# Get Data for :  AEHR
# ./stocks/AEHR.csv  Saved
# Finished
# Get Data for :  AEIS
# ./stocks/AEIS.csv  Saved
# Finished
# Get Data for :  AEL
# ./stocks/AEL.csv  Saved
# Finished
# Get Data for :  AEMD
# ./stocks/AEMD.csv  Saved
# Finished
# Get Data for :  AEO
# ./stocks/AEO.csv  Saved
# Finished
# Get Data for :  AEP
# ./stocks/AEP.csv  Saved
# Finished
# Get Data for :  AERI
# ./stocks/AERI.csv  Saved
# Finished
# Get Data for :  AES
# ./stocks/AES.csv  Saved
# Finished
# Get Data for :  AEY
# ./stocks/AEY.csv  Saved
# Finished
# Get Data for :  AFG
# ./stocks/AFG.csv  Saved
# Finished
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# ./stocks/AFH.csv  Saved
# Finished
# Get Data for :  AFI
# ./stocks/AFI.csv  Saved
# Finished
# Get Data for :  AFIN
# ./stocks/AFIN.csv  Saved
# Finished
# Get Data for :  AFL
# ./stocks/AFL.csv  Saved
# Finished
# Get Data for :  AGCO
# ./stocks/AGCO.csv  Saved
# Finished
# Get Data for :  AGE
# ./stocks/AGE.csv  Saved
# Finished
# Get Data for :  AGEN
# ./stocks/AGEN.csv  Saved
# Finished
# Get Data for :  AGFS
# ./stocks/AGFS.csv  Saved
# Finished
# Get Data for :  AGIO
# ./stocks/AGIO.csv  Saved
# Finished
# Get Data for :  AGLE
# ./stocks/AGLE.csv  Saved
# Finished
# Get Data for :  AGM
# ./stocks/AGM.csv  Saved
# Finished
# Get Data for :  AGNC
# ./stocks/AGNC.csv  Saved
# Finished
# Get Data for :  AGO
# ./stocks/AGO.csv  Saved
# Finished
# Get Data for :  AGR
# ./stocks/AGR.csv  Saved
# Finished
# Get Data for :  AGRX
# ./stocks/AGRX.csv  Saved
# Finished
# Get Data for :  AGS
# ./stocks/AGS.csv  Saved
# Finished
# Get Data for :  AGTC
# ./stocks/AGTC.csv  Saved
# Finished
# Get Data for :  AGX
# ./stocks/AGX.csv  Saved
# Finished
# Get Data for :  AGYS
# ./stocks/AGYS.csv  Saved
# Finished
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# ./stocks/AHC.csv  Saved
# Finished
# Get Data for :  AHH
# ./stocks/AHH.csv  Saved
# Finished
# Get Data for :  AHT
# ./stocks/AHT.csv  Saved
# Finished
# Get Data for :  AIG
# ./stocks/AIG.csv  Saved
# Finished
# Get Data for :  AIMC
# ./stocks/AIMC.csv  Saved
# Finished
# Get Data for :  AIMT
# - AIMT: No data found, symbol may be delisted
# ./stocks/AIMT.csv  Saved
# Finished
# Get Data for :  AIN
# ./stocks/AIN.csv  Saved
# Finished
# Get Data for :  AINC
# ./stocks/AINC.csv  Saved
# Finished
# Get Data for :  AIR
# ./stocks/AIR.csv  Saved
# Finished
# Get Data for :  AIRG
# ./stocks/AIRG.csv  Saved
# Finished
# Get Data for :  AIRI
# ./stocks/AIRI.csv  Saved
# Finished
# Get Data for :  AIRT
# ./stocks/AIRT.csv  Saved
# Finished
# Get Data for :  AIT
# ./stocks/AIT.csv  Saved
# Finished
# Get Data for :  AIV
# ./stocks/AIV.csv  Saved
# Finished
# Get Data for :  AIZ
# ./stocks/AIZ.csv  Saved
# Finished
# Get Data for :  AJG
# ./stocks/AJG.csv  Saved
# Finished
# Get Data for :  AJRD
# ./stocks/AJRD.csv  Saved
# Finished
# Get Data for :  AJX
# ./stocks/AJX.csv  Saved
# Finished
# Get Data for :  AKAM
# ./stocks/AKAM.csv  Saved
# Finished
# Get Data for :  AKBA
# ./stocks/AKBA.csv  Saved
# Finished
# Get Data for :  AKCA
# - AKCA: No data found, symbol may be delisted
# ./stocks/AKCA.csv  Saved
# Finished
# Get Data for :  AKER
# - AKER: No data found, symbol may be delisted
# ./stocks/AKER.csv  Saved
# Finished
# Get Data for :  AKR
# ./stocks/AKR.csv  Saved
# Finished
# Get Data for :  AKTS
# ./stocks/AKTS.csv  Saved
# Finished
# Get Data for :  AL
# ./stocks/AL.csv  Saved
# Finished
# Get Data for :  ALB
# ./stocks/ALB.csv  Saved
# Finished
# Get Data for :  ALBO
# ./stocks/ALBO.csv  Saved
# Finished
# Get Data for :  ALCO
# ./stocks/ALCO.csv  Saved
# Finished
# Get Data for :  ALDX
# ./stocks/ALDX.csv  Saved
# Finished
# Get Data for :  ALE
# ./stocks/ALE.csv  Saved
# Finished
# Get Data for :  ALEC
# ./stocks/ALEC.csv  Saved
# Finished
# Get Data for :  ALEX
# ./stocks/ALEX.csv  Saved
# Finished
# Get Data for :  ALG
# ./stocks/ALG.csv  Saved
# Finished
# Get Data for :  ALGN
# ./stocks/ALGN.csv  Saved
# Finished
# Get Data for :  ALGT
# ./stocks/ALGT.csv  Saved
# Finished
# Get Data for :  ALIM
# ./stocks/ALIM.csv  Saved
# Finished
# Get Data for :  ALJJ
# ./stocks/ALJJ.csv  Saved
# Finished
# Get Data for :  ALK
# ./stocks/ALK.csv  Saved
# Finished
# Get Data for :  ALKS
# ./stocks/ALKS.csv  Saved
# Finished
# Get Data for :  ALL
# ./stocks/ALL.csv  Saved
# Finished
# Get Data for :  ALLE
# ./stocks/ALLE.csv  Saved
# Finished
# Get Data for :  ALLK
# ./stocks/ALLK.csv  Saved
# Finished
# Get Data for :  ALLO
# ./stocks/ALLO.csv  Saved
# Finished
# Get Data for :  ALLY
# ./stocks/ALLY.csv  Saved
# Finished
# Get Data for :  ALNA
# ./stocks/ALNA.csv  Saved
# Finished
# Get Data for :  ALNY
# ./stocks/ALNY.csv  Saved
# Finished
# Get Data for :  ALOT
# ./stocks/ALOT.csv  Saved
# Finished
# Get Data for :  ALPN
# ./stocks/ALPN.csv  Saved
# Finished
# Get Data for :  ALRM
# ./stocks/ALRM.csv  Saved
# Finished
# Get Data for :  ALSK
# - ALSK: No data found, symbol may be delisted
# ./stocks/ALSK.csv  Saved
# Finished
# Get Data for :  ALSN
# ./stocks/ALSN.csv  Saved
# Finished
# Get Data for :  ALT
# ./stocks/ALT.csv  Saved
# Finished
# Get Data for :  ALTM
# ./stocks/ALTM.csv  Saved
# Finished
# Get Data for :  ALTR
# ./stocks/ALTR.csv  Saved
# Finished
# Get Data for :  ALV
# ./stocks/ALV.csv  Saved
# Finished
# Get Data for :  ALX
# ./stocks/ALX.csv  Saved
# Finished
# Get Data for :  ALXN
# - ALXN: No data found, symbol may be delisted
# ./stocks/ALXN.csv  Saved
# Finished
# Get Data for :  AM
# ./stocks/AM.csv  Saved
# Finished
# Get Data for :  AMAG
# - AMAG: No data found, symbol may be delisted
# ./stocks/AMAG.csv  Saved
# Finished
# Get Data for :  AMAL
# ./stocks/AMAL.csv  Saved
# Finished
# Get Data for :  AMAT
# ./stocks/AMAT.csv  Saved
# Finished
# Get Data for :  AMBC
# ./stocks/AMBC.csv  Saved
# Finished
# Get Data for :  AMC
# ./stocks/AMC.csv  Saved
# Finished
# Get Data for :  AMCX
# ./stocks/AMCX.csv  Saved
# Finished
# Get Data for :  AMD
# ./stocks/AMD.csv  Saved
# Finished
# Get Data for :  AME
# ./stocks/AME.csv  Saved
# Finished
# Get Data for :  AMED
# ./stocks/AMED.csv  Saved
# Finished
# Get Data for :  AMG
# ./stocks/AMG.csv  Saved
# Finished
# Get Data for :  AMGN
# ./stocks/AMGN.csv  Saved
# Finished
# Get Data for :  AMH
# ./stocks/AMH.csv  Saved
# Finished
# Get Data for :  AMKR
# ./stocks/AMKR.csv  Saved
# Finished
# Get Data for :  AMN
# ./stocks/AMN.csv  Saved
# Finished
# Get Data for :  AMNB
# ./stocks/AMNB.csv  Saved
# Finished
# Get Data for :  AMOT
# ./stocks/AMOT.csv  Saved
# Finished
# Get Data for :  AMP
# ./stocks/AMP.csv  Saved
# Finished
# Get Data for :  AMPE
# ./stocks/AMPE.csv  Saved
# Finished
# Get Data for :  AMPH
# ./stocks/AMPH.csv  Saved
# Finished
# Get Data for :  AMRB
# - AMRB: No data found, symbol may be delisted
# ./stocks/AMRB.csv  Saved
# Finished
# Get Data for :  AMRC
# ./stocks/AMRC.csv  Saved
# Finished
# Get Data for :  AMRK
# ./stocks/AMRK.csv  Saved
# Finished
# Get Data for :  AMRS
# ./stocks/AMRS.csv  Saved
# Finished
# Get Data for :  AMRX
# ./stocks/AMRX.csv  Saved
# Finished
# Get Data for :  AMS
# ./stocks/AMS.csv  Saved
# Finished
# Get Data for :  AMSC
# ./stocks/AMSC.csv  Saved
# Finished
# Get Data for :  AMSF
# ./stocks/AMSF.csv  Saved
# Finished
# Get Data for :  AMSWA
# ./stocks/AMSWA.csv  Saved
# Finished
# Get Data for :  AMT
# ./stocks/AMT.csv  Saved
# Finished
# Get Data for :  AMTD
# - AMTD: No data found, symbol may be delisted
# ./stocks/AMTD.csv  Saved
# Finished
# Get Data for :  AMTX
# ./stocks/AMTX.csv  Saved
# Finished
# Get Data for :  AMWD
# ./stocks/AMWD.csv  Saved
# Finished
# Get Data for :  AMZN
# ./stocks/AMZN.csv  Saved
# Finished
# Get Data for :  AN
# ./stocks/AN.csv  Saved
# Finished
# Get Data for :  ANAB
# ./stocks/ANAB.csv  Saved
# Finished
# Get Data for :  ANAT
# ./stocks/ANAT.csv  Saved
# Finished
# Get Data for :  ANDE
# ./stocks/ANDE.csv  Saved
# Finished
# Get Data for :  ANET
# ./stocks/ANET.csv  Saved
# Finished
# Get Data for :  ANF
# ./stocks/ANF.csv  Saved
# Finished
# Get Data for :  ANGI
# ./stocks/ANGI.csv  Saved
# Finished
# Get Data for :  ANGO
# ./stocks/ANGO.csv  Saved
# Finished
# Get Data for :  ANH
# - ANH: No data found, symbol may be delisted
# ./stocks/ANH.csv  Saved
# Finished
# Get Data for :  ANIK
# ./stocks/ANIK.csv  Saved
# Finished
# Get Data for :  ANIP
# ./stocks/ANIP.csv  Saved
# Finished
# Get Data for :  ANIX
# ./stocks/ANIX.csv  Saved
# Finished
# Get Data for :  ANSS
# ./stocks/ANSS.csv  Saved
# Finished
# Get Data for :  ANTM
# ./stocks/ANTM.csv  Saved
# Finished
# Get Data for :  AON
# ./stocks/AON.csv  Saved
# Finished
# Get Data for :  AOS
# ./stocks/AOS.csv  Saved
# Finished
# Get Data for :  AOSL
# ./stocks/AOSL.csv  Saved
# Finished
# Get Data for :  AP
# ./stocks/AP.csv  Saved
# Finished
# Get Data for :  APA
# ./stocks/APA.csv  Saved
# Finished
# Get Data for :  APAM
# ./stocks/APAM.csv  Saved
# Finished
# Get Data for :  APD
# ./stocks/APD.csv  Saved
# Finished
# Get Data for :  APDN
# ./stocks/APDN.csv  Saved
# Finished
# Get Data for :  APEI
# ./stocks/APEI.csv  Saved
# Finished
# Get Data for :  APEN
# ./stocks/APEN.csv  Saved
# Finished
# Get Data for :  APH
# ./stocks/APH.csv  Saved
# Finished
# Get Data for :  APLE
# ./stocks/APLE.csv  Saved
# Finished
# Get Data for :  APLS
# ./stocks/APLS.csv  Saved
# Finished
# Get Data for :  APOG
# ./stocks/APOG.csv  Saved
# Finished
# Get Data for :  APPF
# ./stocks/APPF.csv  Saved
# Finished
# Get Data for :  APPN
# ./stocks/APPN.csv  Saved
# Finished
# Get Data for :  APPS
# ./stocks/APPS.csv  Saved
# Finished
# Get Data for :  APRN
# ./stocks/APRN.csv  Saved
# Finished
# Get Data for :  APT
# ./stocks/APT.csv  Saved
# Finished
# Get Data for :  APTS
# ./stocks/APTS.csv  Saved
# Finished
# Get Data for :  APTV
# ./stocks/APTV.csv  Saved
# Finished
# Get Data for :  APVO
# ./stocks/APVO.csv  Saved
# Finished
# Get Data for :  APYX
# ./stocks/APYX.csv  Saved
# Finished
# Get Data for :  AQB
# ./stocks/AQB.csv  Saved
# Finished
# Get Data for :  AQMS
# ./stocks/AQMS.csv  Saved
# Finished
# Get Data for :  AQUA
# ./stocks/AQUA.csv  Saved
# Finished
# Get Data for :  AR
# ./stocks/AR.csv  Saved
# Finished
# Get Data for :  ARA
# - ARA: No data found, symbol may be delisted
# ./stocks/ARA.csv  Saved
# Finished
# Get Data for :  ARAV
# ./stocks/ARAV.csv  Saved
# Finished
# Get Data for :  ARAY
# ./stocks/ARAY.csv  Saved
# Finished
# Get Data for :  ARC
# ./stocks/ARC.csv  Saved
# Finished
# Get Data for :  ARCB
# ./stocks/ARCB.csv  Saved
# Finished
# Get Data for :  ARCH
# ./stocks/ARCH.csv  Saved
# Finished
# Get Data for :  ARDX
# ./stocks/ARDX.csv  Saved
# Finished
# Get Data for :  ARE
# ./stocks/ARE.csv  Saved
# Finished
# Get Data for :  ARES
# ./stocks/ARES.csv  Saved
# Finished
# Get Data for :  ARGO
# ./stocks/ARGO.csv  Saved
# Finished
# Get Data for :  ARI
# ./stocks/ARI.csv  Saved
# Finished
# Get Data for :  ARKR
# ./stocks/ARKR.csv  Saved
# Finished
# Get Data for :  ARL
# ./stocks/ARL.csv  Saved
# Finished
# Get Data for :  ARLO
# ./stocks/ARLO.csv  Saved
# Finished
# Get Data for :  ARMK
# ./stocks/ARMK.csv  Saved
# Finished
# Get Data for :  ARNA
# ./stocks/ARNA.csv  Saved
# Finished
# Get Data for :  ARNC
# ./stocks/ARNC.csv  Saved
# Finished
# Get Data for :  AROC
# ./stocks/AROC.csv  Saved
# Finished
# Get Data for :  AROW
# ./stocks/AROW.csv  Saved
# Finished
# Get Data for :  ARPO
# - ARPO: No data found, symbol may be delisted
# ./stocks/ARPO.csv  Saved
# Finished
# Get Data for :  ARR
# ./stocks/ARR.csv  Saved
# Finished
# Get Data for :  ARTNA
# ./stocks/ARTNA.csv  Saved
# Finished
# Get Data for :  ARTW
# ./stocks/ARTW.csv  Saved
# Finished
# Get Data for :  ARVN
# ./stocks/ARVN.csv  Saved
# Finished
# Get Data for :  ARW
# ./stocks/ARW.csv  Saved
# Finished
# Get Data for :  ARWR
# ./stocks/ARWR.csv  Saved
# Finished
# Get Data for :  ASB
# ./stocks/ASB.csv  Saved
# Finished
# Get Data for :  ASFI
# - ASFI: No data found, symbol may be delisted
# ./stocks/ASFI.csv  Saved
# Finished
# Get Data for :  ASGN
# ./stocks/ASGN.csv  Saved
# Finished
# Get Data for :  ASH
# ./stocks/ASH.csv  Saved
# Finished
# Get Data for :  ASIX
# ./stocks/ASIX.csv  Saved
# Finished
# Get Data for :  ASMB
# ./stocks/ASMB.csv  Saved
# Finished
# Get Data for :  ASNA
# - ASNA: No data found, symbol may be delisted
# ./stocks/ASNA.csv  Saved
# Finished
# Get Data for :  ASPN
# ./stocks/ASPN.csv  Saved
# Finished
# Get Data for :  ASPS
# ./stocks/ASPS.csv  Saved
# Finished
# Get Data for :  ASRT
# ./stocks/ASRT.csv  Saved
# Finished
# Get Data for :  ASRV
# ./stocks/ASRV.csv  Saved
# Finished
# Get Data for :  ASTC
# ./stocks/ASTC.csv  Saved
# Finished
# Get Data for :  ASTE
# ./stocks/ASTE.csv  Saved
# Finished
# Get Data for :  ASUR
# ./stocks/ASUR.csv  Saved
# Finished
# Get Data for :  ASYS
# ./stocks/ASYS.csv  Saved
# Finished
# Get Data for :  ATEC
# ./stocks/ATEC.csv  Saved
# Finished
# Get Data for :  ATEN
# ./stocks/ATEN.csv  Saved
# Finished
# Get Data for :  ATGE
# ./stocks/ATGE.csv  Saved
# Finished
# Get Data for :  ATH
# ./stocks/ATH.csv  Saved
# Finished
# Get Data for :  ATHX
# ./stocks/ATHX.csv  Saved
# Finished
# Get Data for :  ATI
# ./stocks/ATI.csv  Saved
# Finished
# Get Data for :  ATKR
# ./stocks/ATKR.csv  Saved
# Finished
# Get Data for :  ATLC
# ./stocks/ATLC.csv  Saved
# Finished
# Get Data for :  ATLO
# ./stocks/ATLO.csv  Saved
# Finished
# Get Data for :  ATNI
# ./stocks/ATNI.csv  Saved
# Finished
# Get Data for :  ATNM
# ./stocks/ATNM.csv  Saved
# Finished
# Get Data for :  ATNX
# ./stocks/ATNX.csv  Saved
# Finished
# Get Data for :  ATO
# ./stocks/ATO.csv  Saved
# Finished
# Get Data for :  ATOS
# ./stocks/ATOS.csv  Saved
# Finished
# Get Data for :  ATR
# ./stocks/ATR.csv  Saved
# Finished
# Get Data for :  ATRA
# ./stocks/ATRA.csv  Saved
# Finished
# Get Data for :  ATRC
# ./stocks/ATRC.csv  Saved
# Finished
# Get Data for :  ATRI
# ./stocks/ATRI.csv  Saved
# Finished
# Get Data for :  ATRO
# ./stocks/ATRO.csv  Saved
# Finished
# Get Data for :  ATRS
# ./stocks/ATRS.csv  Saved
# Finished
# Get Data for :  ATSG
# ./stocks/ATSG.csv  Saved
# Finished
# Get Data for :  ATUS
# ./stocks/ATUS.csv  Saved
# Finished
# Get Data for :  ATVI
# ./stocks/ATVI.csv  Saved
# Finished
# Get Data for :  AUBN
# ./stocks/AUBN.csv  Saved
# Finished
# Get Data for :  AUMN
# ./stocks/AUMN.csv  Saved
# Finished
# Get Data for :  AUTO
# ./stocks/AUTO.csv  Saved
# Finished
# Get Data for :  AVA
# ./stocks/AVA.csv  Saved
# Finished
# Get Data for :  AVAV
# ./stocks/AVAV.csv  Saved
# Finished
# Get Data for :  AVB
# ./stocks/AVB.csv  Saved
# Finished
# Get Data for :  AVD
# ./stocks/AVD.csv  Saved
# Finished
# Get Data for :  AVEO
# ./stocks/AVEO.csv  Saved
# Finished
# Get Data for :  AVGO
# ./stocks/AVGO.csv  Saved
# Finished
# Get Data for :  AVGR
# ./stocks/AVGR.csv  Saved
# Finished
# Get Data for :  AVID
# ./stocks/AVID.csv  Saved
# Finished
# Get Data for :  AVLR
# ./stocks/AVLR.csv  Saved
# Finished
# Get Data for :  AVNS
# ./stocks/AVNS.csv  Saved
# Finished
# Get Data for :  AVNW
# ./stocks/AVNW.csv  Saved
# Finished
# Get Data for :  AVRO
# ./stocks/AVRO.csv  Saved
# Finished
# Get Data for :  AVT
# ./stocks/AVT.csv  Saved
# Finished
# Get Data for :  AVTR
# ./stocks/AVTR.csv  Saved
# Finished
# Get Data for :  AVXL
# ./stocks/AVXL.csv  Saved
# Finished
# Get Data for :  AVY
# ./stocks/AVY.csv  Saved
# Finished
# Get Data for :  AVYA
# ./stocks/AVYA.csv  Saved
# Finished
# Get Data for :  AWI
# ./stocks/AWI.csv  Saved
# Finished
# Get Data for :  AWK
# ./stocks/AWK.csv  Saved
# Finished
# Get Data for :  AWR
# ./stocks/AWR.csv  Saved
# Finished
# Get Data for :  AWRE
# ./stocks/AWRE.csv  Saved
# Finished
# Get Data for :  AWSM
# - AWSM: No data found, symbol may be delisted
# ./stocks/AWSM.csv  Saved
# Finished
# Get Data for :  AX
# ./stocks/AX.csv  Saved
# Finished
# Get Data for :  AXAS
# ./stocks/AXAS.csv  Saved
# Finished
# Get Data for :  AXDX
# ./stocks/AXDX.csv  Saved
# Finished
# Get Data for :  AXE
# - AXE: No data found, symbol may be delisted
# ./stocks/AXE.csv  Saved
# Finished
# Get Data for :  AXGN
# ./stocks/AXGN.csv  Saved
# Finished
# Get Data for :  AXL
# ./stocks/AXL.csv  Saved
# Finished
# Get Data for :  AXNX
# ./stocks/AXNX.csv  Saved
# Finished
# Get Data for :  AXP
# ./stocks/AXP.csv  Saved
# Finished
# Get Data for :  AXR
# ./stocks/AXR.csv  Saved
# Finished
# Get Data for :  AXS
# ./stocks/AXS.csv  Saved
# Finished
# Get Data for :  AXSM
# ./stocks/AXSM.csv  Saved
# Finished
# Get Data for :  AXTA
# ./stocks/AXTA.csv  Saved
# Finished
# Get Data for :  AXTI
# ./stocks/AXTI.csv  Saved
# Finished
# Get Data for :  AYI
# ./stocks/AYI.csv  Saved
# Finished
# Get Data for :  AYX
# ./stocks/AYX.csv  Saved
# Finished
# Get Data for :  AZO
# ./stocks/AZO.csv  Saved
# Finished
# Get Data for :  AZPN
# ./stocks/AZPN.csv  Saved
# Finished
# Get Data for :  AZZ
# ./stocks/AZZ.csv  Saved
# Finished
# Get Data for :  B
# ./stocks/B.csv  Saved
# Finished
# Get Data for :  BA
# ./stocks/BA.csv  Saved
# Finished
# Get Data for :  BAC
# ./stocks/BAC.csv  Saved
# Finished
# Get Data for :  BAH
# ./stocks/BAH.csv  Saved
# Finished
# Get Data for :  BANC
# ./stocks/BANC.csv  Saved
# Finished
# Get Data for :  BAND
# ./stocks/BAND.csv  Saved
# Finished
# Get Data for :  BANF
# ./stocks/BANF.csv  Saved
# Finished
# Get Data for :  BANR
# ./stocks/BANR.csv  Saved
# Finished
# Get Data for :  BASI
# - BASI: No data found, symbol may be delisted
# ./stocks/BASI.csv  Saved
# Finished
# Get Data for :  BATRA
# ./stocks/BATRA.csv  Saved
# Finished
# Get Data for :  BATRK
# ./stocks/BATRK.csv  Saved
# Finished
# Get Data for :  BAX
# ./stocks/BAX.csv  Saved
# Finished
# Get Data for :  BBBY
# ./stocks/BBBY.csv  Saved
# Finished
# Get Data for :  BBCP
# ./stocks/BBCP.csv  Saved
# Finished
# Get Data for :  BBGI
# ./stocks/BBGI.csv  Saved
# Finished
# Get Data for :  BBSI
# ./stocks/BBSI.csv  Saved
# Finished
# Get Data for :  BBW
# ./stocks/BBW.csv  Saved
# Finished
# Get Data for :  BBY
# ./stocks/BBY.csv  Saved
# Finished
# Get Data for :  BC
# ./stocks/BC.csv  Saved
# Finished
# Get Data for :  BCBP
# ./stocks/BCBP.csv  Saved
# Finished
# Get Data for :  BCC
# ./stocks/BCC.csv  Saved
# Finished
# Get Data for :  BCEI
# - BCEI: No data found, symbol may be delisted
# ./stocks/BCEI.csv  Saved
# Finished
# Get Data for :  BCLI
# ./stocks/BCLI.csv  Saved
# Finished
# Get Data for :  BCO
# ./stocks/BCO.csv  Saved
# Finished
# Get Data for :  BCOR
# ./stocks/BCOR.csv  Saved
# Finished
# Get Data for :  BCOV
# ./stocks/BCOV.csv  Saved
# Finished
# Get Data for :  BCPC
# ./stocks/BCPC.csv  Saved
# Finished
# Get Data for :  BCRX
# ./stocks/BCRX.csv  Saved
# Finished
# Get Data for :  BDC
# ./stocks/BDC.csv  Saved
# Finished
# Get Data for :  BDGE
# - BDGE: No data found, symbol may be delisted
# ./stocks/BDGE.csv  Saved
# Finished
# Get Data for :  BDL
# ./stocks/BDL.csv  Saved
# Finished
# Get Data for :  BDN
# ./stocks/BDN.csv  Saved
# Finished
# Get Data for :  BDSI
# ./stocks/BDSI.csv  Saved
# Finished
# Get Data for :  BDX
# ./stocks/BDX.csv  Saved
# Finished
# Get Data for :  BE
# ./stocks/BE.csv  Saved
# Finished
# Get Data for :  BEAT
# ./stocks/BEAT.csv  Saved
# Finished
# Get Data for :  BECN
# ./stocks/BECN.csv  Saved
# Finished
# Get Data for :  BELFA
# ./stocks/BELFA.csv  Saved
# Finished
# Get Data for :  BELFB
# ./stocks/BELFB.csv  Saved
# Finished
# Get Data for :  BEN
# ./stocks/BEN.csv  Saved
# Finished
# Get Data for :  BERY
# ./stocks/BERY.csv  Saved
# Finished
# Get Data for :  BFAM
# ./stocks/BFAM.csv  Saved
# Finished
# Get Data for :  BFIN
# ./stocks/BFIN.csv  Saved
# Finished
# Get Data for :  BFS
# ./stocks/BFS.csv  Saved
# Finished
# Get Data for :  BFST
# ./stocks/BFST.csv  Saved
# Finished
# Get Data for :  BG
# ./stocks/BG.csv  Saved
# Finished
# Get Data for :  BGCP
# ./stocks/BGCP.csv  Saved
# Finished
# Get Data for :  BGFV
# ./stocks/BGFV.csv  Saved
# Finished
# Get Data for :  BGS
# ./stocks/BGS.csv  Saved
# Finished
# Get Data for :  BGSF
# ./stocks/BGSF.csv  Saved
# Finished
# Get Data for :  BH
# ./stocks/BH.csv  Saved
# Finished
# Get Data for :  BHB
# ./stocks/BHB.csv  Saved
# Finished
# Get Data for :  BHE
# ./stocks/BHE.csv  Saved
# Finished
# Get Data for :  BHF
# ./stocks/BHF.csv  Saved
# Finished
# Get Data for :  BHLB
# ./stocks/BHLB.csv  Saved
# Finished
# Get Data for :  BHR
# ./stocks/BHR.csv  Saved
# Finished
# Get Data for :  BHVN
# ./stocks/BHVN.csv  Saved
# Finished
# Get Data for :  BIG
# ./stocks/BIG.csv  Saved
# Finished
# Get Data for :  BIIB
# ./stocks/BIIB.csv  Saved
# Finished
# Get Data for :  BIO
# ./stocks/BIO.csv  Saved
# Finished
# Get Data for :  BIOC
# ./stocks/BIOC.csv  Saved
# Finished
# Get Data for :  BIOL
# ./stocks/BIOL.csv  Saved
# Finished
# Get Data for :  BJ
# ./stocks/BJ.csv  Saved
# Finished
# Get Data for :  BJRI
# ./stocks/BJRI.csv  Saved
# Finished
# Get Data for :  BK
# ./stocks/BK.csv  Saved
# Finished
# Get Data for :  BKD
# ./stocks/BKD.csv  Saved
# Finished
# Get Data for :  BKE
# ./stocks/BKE.csv  Saved
# Finished
# Get Data for :  BKH
# ./stocks/BKH.csv  Saved
# Finished
# Get Data for :  BKI
# ./stocks/BKI.csv  Saved
# Finished
# Get Data for :  BKNG
# ./stocks/BKNG.csv  Saved
# Finished
# Get Data for :  BKSC
# ./stocks/BKSC.csv  Saved
# Finished
# Get Data for :  BKTI
# ./stocks/BKTI.csv  Saved
# Finished
# Get Data for :  BKU
# ./stocks/BKU.csv  Saved
# Finished
# Get Data for :  BL
# ./stocks/BL.csv  Saved
# Finished
# Get Data for :  BLBD
# ./stocks/BLBD.csv  Saved
# Finished
# Get Data for :  BLCM
# ./stocks/BLCM.csv  Saved
# Finished
# Get Data for :  BLD
# ./stocks/BLD.csv  Saved
# Finished
# Get Data for :  BLDR
# ./stocks/BLDR.csv  Saved
# Finished
# Get Data for :  BLFS
# ./stocks/BLFS.csv  Saved
# Finished
# Get Data for :  BLK
# ./stocks/BLK.csv  Saved
# Finished
# Get Data for :  BLKB
# ./stocks/BLKB.csv  Saved
# Finished
# Get Data for :  BLL
# ./stocks/BLL.csv  Saved
# Finished
# Get Data for :  BLMN
# ./stocks/BLMN.csv  Saved
# Finished
# Get Data for :  BLUE
# ./stocks/BLUE.csv  Saved
# Finished
# Get Data for :  BMCH
# - BMCH: No data found, symbol may be delisted
# ./stocks/BMCH.csv  Saved
# Finished
# Get Data for :  BMI
# ./stocks/BMI.csv  Saved
# Finished
# Get Data for :  BMRC
# ./stocks/BMRC.csv  Saved
# Finished
# Get Data for :  BMRN
# ./stocks/BMRN.csv  Saved
# Finished
# Get Data for :  BMTC
# ./stocks/BMTC.csv  Saved
# Finished
# Get Data for :  BMY
# ./stocks/BMY.csv  Saved
# Finished
# Get Data for :  BNED
# ./stocks/BNED.csv  Saved
# Finished
# Get Data for :  BNFT
# ./stocks/BNFT.csv  Saved
# Finished
# Get Data for :  BOCH
# - BOCH: No data found, symbol may be delisted
# ./stocks/BOCH.csv  Saved
# Finished
# Get Data for :  BOH
# ./stocks/BOH.csv  Saved
# Finished
# Get Data for :  BOKF
# ./stocks/BOKF.csv  Saved
# Finished
# Get Data for :  BOMN
# ./stocks/BOMN.csv  Saved
# Finished
# Get Data for :  BOOM
# ./stocks/BOOM.csv  Saved
# Finished
# Get Data for :  BOOT
# ./stocks/BOOT.csv  Saved
# Finished
# Get Data for :  BOTJ
# ./stocks/BOTJ.csv  Saved
# Finished
# Get Data for :  BOX
# ./stocks/BOX.csv  Saved
# Finished
# Get Data for :  BPFH
# - BPFH: No data found, symbol may be delisted
# ./stocks/BPFH.csv  Saved
# Finished
# Get Data for :  BPMC
# ./stocks/BPMC.csv  Saved
# Finished
# Get Data for :  BPOP
# ./stocks/BPOP.csv  Saved
# Finished
# Get Data for :  BPRN
# ./stocks/BPRN.csv  Saved
# Finished
# Get Data for :  BPTH
# ./stocks/BPTH.csv  Saved
# Finished
# Get Data for :  BR
# ./stocks/BR.csv  Saved
# Finished
# Get Data for :  BRC
# ./stocks/BRC.csv  Saved
# Finished
# Get Data for :  BREW
# - BREW: No data found, symbol may be delisted
# ./stocks/BREW.csv  Saved
# Finished
# Get Data for :  BRG
# ./stocks/BRG.csv  Saved
# Finished
# Get Data for :  BRID
# ./stocks/BRID.csv  Saved
# Finished
# Get Data for :  BRKL
# ./stocks/BRKL.csv  Saved
# Finished
# Get Data for :  BRKR
# ./stocks/BRKR.csv  Saved
# Finished
# Get Data for :  BRKS
# ./stocks/BRKS.csv  Saved
# Finished
# Get Data for :  BRN
# ./stocks/BRN.csv  Saved
# Finished
# Get Data for :  BRO
# ./stocks/BRO.csv  Saved
# Finished
# Get Data for :  BRT
# ./stocks/BRT.csv  Saved
# Finished
# Get Data for :  BRX
# ./stocks/BRX.csv  Saved
# Finished
# Get Data for :  BRY
# ./stocks/BRY.csv  Saved
# Finished
# Get Data for :  BSET
# ./stocks/BSET.csv  Saved
# Finished
# Get Data for :  BSGM
# ./stocks/BSGM.csv  Saved
# Finished
# Get Data for :  BSQR
# ./stocks/BSQR.csv  Saved
# Finished
# Get Data for :  BSRR
# ./stocks/BSRR.csv  Saved
# Finished
# Get Data for :  BSTC
# - BSTC: No data found, symbol may be delisted
# ./stocks/BSTC.csv  Saved
# Finished
# Get Data for :  BSX
# ./stocks/BSX.csv  Saved
# Finished
# Get Data for :  BTN
# ./stocks/BTN.csv  Saved
# Finished
# Get Data for :  BTU
# ./stocks/BTU.csv  Saved
# Finished
# Get Data for :  BURL
# ./stocks/BURL.csv  Saved
# Finished
# Get Data for :  BUSE
# ./stocks/BUSE.csv  Saved
# Finished
# Get Data for :  BV
# ./stocks/BV.csv  Saved
# Finished
# Get Data for :  BW
# ./stocks/BW.csv  Saved
# Finished
# Get Data for :  BWA
# ./stocks/BWA.csv  Saved
# Finished
# Get Data for :  BWEN
# ./stocks/BWEN.csv  Saved
# Finished
# Get Data for :  BWFG
# ./stocks/BWFG.csv  Saved
# Finished
# Get Data for :  BWXT
# ./stocks/BWXT.csv  Saved
# Finished
# Get Data for :  BXC
# ./stocks/BXC.csv  Saved
# Finished
# Get Data for :  BXMT
# ./stocks/BXMT.csv  Saved
# Finished
# Get Data for :  BXP
# ./stocks/BXP.csv  Saved
# Finished
# Get Data for :  BXS
# - BXS: No data found, symbol may be delisted
# ./stocks/BXS.csv  Saved
# Finished
# Get Data for :  BY
# ./stocks/BY.csv  Saved
# Finished
# Get Data for :  BYD
# ./stocks/BYD.csv  Saved
# Finished
# Get Data for :  BYFC
# ./stocks/BYFC.csv  Saved
# Finished
# Get Data for :  BYND
# ./stocks/BYND.csv  Saved
# Finished
# Get Data for :  BZH
# ./stocks/BZH.csv  Saved
# Finished
# Get Data for :  C
# ./stocks/C.csv  Saved
# Finished
# Get Data for :  CABO
# ./stocks/CABO.csv  Saved
# Finished
# Get Data for :  CAC
# ./stocks/CAC.csv  Saved
# Finished
# Get Data for :  CACC
# ./stocks/CACC.csv  Saved
# Finished
# Get Data for :  CACI
# ./stocks/CACI.csv  Saved
# Finished
# Get Data for :  CADE
# ./stocks/CADE.csv  Saved
# Finished
# Get Data for :  CAG
# ./stocks/CAG.csv  Saved
# Finished
# Get Data for :  CAH
# ./stocks/CAH.csv  Saved
# Finished
# Get Data for :  CAI
# ./stocks/CAI.csv  Saved
# Finished
# Get Data for :  CAKE
# ./stocks/CAKE.csv  Saved
# Finished
# Get Data for :  CAL
# ./stocks/CAL.csv  Saved
# Finished
# Get Data for :  CALA
# ./stocks/CALA.csv  Saved
# Finished
# Get Data for :  CALM
# ./stocks/CALM.csv  Saved
# Finished
# Get Data for :  CALX
# ./stocks/CALX.csv  Saved
# Finished
# Get Data for :  CAMP
# ./stocks/CAMP.csv  Saved
# Finished
# Get Data for :  CAPR
# ./stocks/CAPR.csv  Saved
# Finished
# Get Data for :  CAR
# ./stocks/CAR.csv  Saved
# Finished
# Get Data for :  CARA
# ./stocks/CARA.csv  Saved
# Finished
# Get Data for :  CARG
# ./stocks/CARG.csv  Saved
# Finished
# Get Data for :  CARS
# ./stocks/CARS.csv  Saved
# Finished
# Get Data for :  CASA
# ./stocks/CASA.csv  Saved
# Finished
# Get Data for :  CASH
# ./stocks/CASH.csv  Saved
# Finished
# Get Data for :  CASI
# ./stocks/CASI.csv  Saved
# Finished
# Get Data for :  CASS
# ./stocks/CASS.csv  Saved
# Finished
# Get Data for :  CASY
# ./stocks/CASY.csv  Saved
# Finished
# Get Data for :  CAT
# ./stocks/CAT.csv  Saved
# Finished
# Get Data for :  CATB
# - CATB: No data found, symbol may be delisted
# ./stocks/CATB.csv  Saved
# Finished
# Get Data for :  CATC
# ./stocks/CATC.csv  Saved
# Finished
# Get Data for :  CATM
# - CATM: No data found, symbol may be delisted
# ./stocks/CATM.csv  Saved
# Finished
# Get Data for :  CATO
# ./stocks/CATO.csv  Saved
# Finished
# Get Data for :  CATS
# - CATS: No data found, symbol may be delisted
# ./stocks/CATS.csv  Saved
# Finished
# Get Data for :  CATY
# ./stocks/CATY.csv  Saved
# Finished
# Get Data for :  CB
# ./stocks/CB.csv  Saved
# Finished
# Get Data for :  CBAN
# ./stocks/CBAN.csv  Saved
# Finished
# Get Data for :  CBAY
# ./stocks/CBAY.csv  Saved
# Finished
# Get Data for :  CBB
# - CBB: No data found, symbol may be delisted
# ./stocks/CBB.csv  Saved
# Finished
# Get Data for :  CBFV
# ./stocks/CBFV.csv  Saved
# Finished
# Get Data for :  CBIO
# ./stocks/CBIO.csv  Saved
# Finished
# Get Data for :  CBLI
# - CBLI: No data found, symbol may be delisted
# ./stocks/CBLI.csv  Saved
# Finished
# Get Data for :  CBMG
# - CBMG: No data found, symbol may be delisted
# ./stocks/CBMG.csv  Saved
# Finished
# Get Data for :  CBOE
# ./stocks/CBOE.csv  Saved
# Finished
# Get Data for :  CBRE
# ./stocks/CBRE.csv  Saved
# Finished
# Get Data for :  CBRL
# ./stocks/CBRL.csv  Saved
# Finished
# Get Data for :  CBSH
# ./stocks/CBSH.csv  Saved
# Finished
# Get Data for :  CBT
# ./stocks/CBT.csv  Saved
# Finished
# Get Data for :  CBTX
# ./stocks/CBTX.csv  Saved
# Finished
# Get Data for :  CBU
# ./stocks/CBU.csv  Saved
# Finished
# Get Data for :  CBZ
# ./stocks/CBZ.csv  Saved
# Finished
# Get Data for :  CC
# ./stocks/CC.csv  Saved
# Finished
# Get Data for :  CCBG
# ./stocks/CCBG.csv  Saved
# Finished
# Get Data for :  CCF
# ./stocks/CCF.csv  Saved
# Finished
# Get Data for :  CCI
# ./stocks/CCI.csv  Saved
# Finished
# Get Data for :  CCK
# ./stocks/CCK.csv  Saved
# Finished
# Get Data for :  CCL
# ./stocks/CCL.csv  Saved
# Finished
# Get Data for :  CCMP
# ./stocks/CCMP.csv  Saved
# Finished
# Get Data for :  CCNE
# ./stocks/CCNE.csv  Saved
# Finished
# Get Data for :  CCO
# ./stocks/CCO.csv  Saved
# Finished
# Get Data for :  CCOI
# ./stocks/CCOI.csv  Saved
# Finished
# Get Data for :  CCRN
# ./stocks/CCRN.csv  Saved
# Finished
# Get Data for :  CCS
# ./stocks/CCS.csv  Saved
# Finished
# Get Data for :  CCXI
# ./stocks/CCXI.csv  Saved
# Finished
# Get Data for :  CDAY
# ./stocks/CDAY.csv  Saved
# Finished
# Get Data for :  CDE
# ./stocks/CDE.csv  Saved
# Finished
# Get Data for :  CDEV
# ./stocks/CDEV.csv  Saved
# Finished
# Get Data for :  CDK
# ./stocks/CDK.csv  Saved
# Finished
# Get Data for :  CDLX
# ./stocks/CDLX.csv  Saved
# Finished
# Get Data for :  CDMO
# ./stocks/CDMO.csv  Saved
# Finished
# Get Data for :  CDNA
# ./stocks/CDNA.csv  Saved
# Finished
# Get Data for :  CDNS
# ./stocks/CDNS.csv  Saved
# Finished
# Get Data for :  CDR
# ./stocks/CDR.csv  Saved
# Finished
# Get Data for :  CDTX
# ./stocks/CDTX.csv  Saved
# Finished
# Get Data for :  CDW
# ./stocks/CDW.csv  Saved
# Finished
# Get Data for :  CDXC
# ./stocks/CDXC.csv  Saved
# Finished
# Get Data for :  CDXS
# ./stocks/CDXS.csv  Saved
# Finished
# Get Data for :  CDZI
# ./stocks/CDZI.csv  Saved
# Finished
# Get Data for :  CE
# ./stocks/CE.csv  Saved
# Finished
# Get Data for :  CECE
# ./stocks/CECE.csv  Saved
# Finished
# Get Data for :  CEI
# ./stocks/CEI.csv  Saved
# Finished
# Get Data for :  CEIX
# ./stocks/CEIX.csv  Saved
# Finished
# Get Data for :  CELC
# ./stocks/CELC.csv  Saved
# Finished
# Get Data for :  CELH
# ./stocks/CELH.csv  Saved
# Finished
# Get Data for :  CEMI
# ./stocks/CEMI.csv  Saved
# Finished
# Get Data for :  CENT
# ./stocks/CENT.csv  Saved
# Finished
# Get Data for :  CENTA
# ./stocks/CENTA.csv  Saved
# Finished
# Get Data for :  CENX
# ./stocks/CENX.csv  Saved
# Finished
# Get Data for :  CERC
# - CERC: No data found, symbol may be delisted
# ./stocks/CERC.csv  Saved
# Finished
# Get Data for :  CERN
# ./stocks/CERN.csv  Saved
# Finished
# Get Data for :  CERS
# ./stocks/CERS.csv  Saved
# Finished
# Get Data for :  CETV
# - CETV: No data found, symbol may be delisted
# ./stocks/CETV.csv  Saved
# Finished
# Get Data for :  CETX
# ./stocks/CETX.csv  Saved
# Finished
# Get Data for :  CEVA
# ./stocks/CEVA.csv  Saved
# Finished
# Get Data for :  CF
# ./stocks/CF.csv  Saved
# Finished
# Get Data for :  CFBK
# ./stocks/CFBK.csv  Saved
# Finished
# Get Data for :  CFFI
# ./stocks/CFFI.csv  Saved
# Finished
# Get Data for :  CFFN
# ./stocks/CFFN.csv  Saved
# Finished
# Get Data for :  CFG
# ./stocks/CFG.csv  Saved
# Finished
# Get Data for :  CFMS
# ./stocks/CFMS.csv  Saved
# Finished
# Get Data for :  CFR
# ./stocks/CFR.csv  Saved
# Finished
# Get Data for :  CFX
# ./stocks/CFX.csv  Saved
# Finished
# Get Data for :  CGIX
# - CGIX: No data found, symbol may be delisted
# ./stocks/CGIX.csv  Saved
# Finished
# Get Data for :  CGNX
# ./stocks/CGNX.csv  Saved
# Finished
# Get Data for :  CHAP
# - CHAP: No data found, symbol may be delisted
# ./stocks/CHAP.csv  Saved
# Finished
# Get Data for :  CHCI
# ./stocks/CHCI.csv  Saved
# Finished
# Get Data for :  CHCO
# ./stocks/CHCO.csv  Saved
# Finished
# Get Data for :  CHCT
# ./stocks/CHCT.csv  Saved
# Finished
# Get Data for :  CHD
# ./stocks/CHD.csv  Saved
# Finished
# Get Data for :  CHDN
# ./stocks/CHDN.csv  Saved
# Finished
# Get Data for :  CHE
# ./stocks/CHE.csv  Saved
# Finished
# Get Data for :  CHEF
# ./stocks/CHEF.csv  Saved
# Finished
# Get Data for :  CHGG
# ./stocks/CHGG.csv  Saved
# Finished
# Get Data for :  CHH
# ./stocks/CHH.csv  Saved
# Finished
# Get Data for :  CHK
# ./stocks/CHK.csv  Saved
# Finished
# Get Data for :  CHMA
# ./stocks/CHMA.csv  Saved
# Finished
# Get Data for :  CHMG
# ./stocks/CHMG.csv  Saved
# Finished
# Get Data for :  CHMI
# ./stocks/CHMI.csv  Saved
# Finished
# Get Data for :  CHRS
# ./stocks/CHRS.csv  Saved
# Finished
# Get Data for :  CHRW
# ./stocks/CHRW.csv  Saved
# Finished
# Get Data for :  CHS
# ./stocks/CHS.csv  Saved
# Finished
# Get Data for :  CHTR
# ./stocks/CHTR.csv  Saved
# Finished
# Get Data for :  CHUY
# ./stocks/CHUY.csv  Saved
# Finished
# Get Data for :  CI
# ./stocks/CI.csv  Saved
# Finished
# Get Data for :  CIA
# ./stocks/CIA.csv  Saved
# Finished
# Get Data for :  CIDM
# ./stocks/CIDM.csv  Saved
# Finished
# Get Data for :  CIEN
# ./stocks/CIEN.csv  Saved
# Finished
# Get Data for :  CIM
# ./stocks/CIM.csv  Saved
# Finished
# Get Data for :  CINF
# ./stocks/CINF.csv  Saved
# Finished
# Get Data for :  CIO
# ./stocks/CIO.csv  Saved
# Finished
# Get Data for :  CIR
# ./stocks/CIR.csv  Saved
# Finished
# Get Data for :  CIT
# ./stocks/CIT.csv  Saved
# Finished
# Get Data for :  CIVB
# ./stocks/CIVB.csv  Saved
# Finished
# Get Data for :  CIX
# ./stocks/CIX.csv  Saved
# Finished
# Get Data for :  CIZN
# ./stocks/CIZN.csv  Saved
# Finished
# Get Data for :  CKH
# - CKH: No data found, symbol may be delisted
# ./stocks/CKH.csv  Saved
# Finished
# Get Data for :  CKX
# ./stocks/CKX.csv  Saved
# Finished
# Get Data for :  CL
# ./stocks/CL.csv  Saved
# Finished
# Get Data for :  CLAR
# ./stocks/CLAR.csv  Saved
# Finished
# Get Data for :  CLB
# ./stocks/CLB.csv  Saved
# Finished
# Get Data for :  CLBS
# ./stocks/CLBS.csv  Saved
# Finished
# Get Data for :  CLCT
# - CLCT: No data found, symbol may be delisted
# ./stocks/CLCT.csv  Saved
# Finished
# Get Data for :  CLDR
# - CLDR: No data found, symbol may be delisted
# ./stocks/CLDR.csv  Saved
# Finished
# Get Data for :  CLDT
# ./stocks/CLDT.csv  Saved
# Finished
# Get Data for :  CLDX
# ./stocks/CLDX.csv  Saved
# Finished
# Get Data for :  CLF
# ./stocks/CLF.csv  Saved
# Finished
# Get Data for :  CLFD
# ./stocks/CLFD.csv  Saved
# Finished
# Get Data for :  CLGX
# - CLGX: No data found, symbol may be delisted
# ./stocks/CLGX.csv  Saved
# Finished
# Get Data for :  CLH
# ./stocks/CLH.csv  Saved
# Finished
# Get Data for :  CLI
# ./stocks/CLI.csv  Saved
# Finished
# Get Data for :  CLIR
# ./stocks/CLIR.csv  Saved
# Finished
# Get Data for :  CLNC
# - CLNC: No data found, symbol may be delisted
# ./stocks/CLNC.csv  Saved
# Finished
# Get Data for :  CLNE
# ./stocks/CLNE.csv  Saved
# Finished
# Get Data for :  CLNY
# - CLNY: No data found, symbol may be delisted
# ./stocks/CLNY.csv  Saved
# Finished
# Get Data for :  CLPR
# ./stocks/CLPR.csv  Saved
# Finished
# Get Data for :  CLR
# ./stocks/CLR.csv  Saved
# Finished
# Get Data for :  CLRB
# ./stocks/CLRB.csv  Saved
# Finished
# Get Data for :  CLRO
# ./stocks/CLRO.csv  Saved
# Finished
# Get Data for :  CLSN
# ./stocks/CLSN.csv  Saved
# Finished
# Get Data for :  CLUB
# - CLUB: No data found, symbol may be delisted
# ./stocks/CLUB.csv  Saved
# Finished
# Get Data for :  CLVS
# ./stocks/CLVS.csv  Saved
# Finished
# Get Data for :  CLW
# ./stocks/CLW.csv  Saved
# Finished
# Get Data for :  CLX
# ./stocks/CLX.csv  Saved
# Finished
# Get Data for :  CLXT
# ./stocks/CLXT.csv  Saved
# Finished
# Get Data for :  CMA
# ./stocks/CMA.csv  Saved
# Finished
# Get Data for :  CMC
# ./stocks/CMC.csv  Saved
# Finished
# Get Data for :  CMCO
# ./stocks/CMCO.csv  Saved
# Finished
# Get Data for :  CMCSA
# ./stocks/CMCSA.csv  Saved
# Finished
# Get Data for :  CMCT
# ./stocks/CMCT.csv  Saved
# Finished
# Get Data for :  CMD
# - CMD: No data found, symbol may be delisted
# ./stocks/CMD.csv  Saved
# Finished
# Get Data for :  CME
# ./stocks/CME.csv  Saved
# Finished
# Get Data for :  CMG
# ./stocks/CMG.csv  Saved
# Finished
# Get Data for :  CMI
# ./stocks/CMI.csv  Saved
# Finished
# Get Data for :  CMO
# - CMO: No data found, symbol may be delisted
# ./stocks/CMO.csv  Saved
# Finished
# Get Data for :  CMP
# ./stocks/CMP.csv  Saved
# Finished
# Get Data for :  CMRX
# ./stocks/CMRX.csv  Saved
# Finished
# Get Data for :  CMS
# ./stocks/CMS.csv  Saved
# Finished
# Get Data for :  CMT
# ./stocks/CMT.csv  Saved
# Finished
# Get Data for :  CMTL
# ./stocks/CMTL.csv  Saved
# Finished
# Get Data for :  CNA
# ./stocks/CNA.csv  Saved
# Finished
# Get Data for :  CNBKA
# ./stocks/CNBKA.csv  Saved
# Finished
# Get Data for :  CNC
# ./stocks/CNC.csv  Saved
# Finished
# Get Data for :  CNCE
# ./stocks/CNCE.csv  Saved
# Finished
# Get Data for :  CNDT
# ./stocks/CNDT.csv  Saved
# Finished
# Get Data for :  CNFR
# ./stocks/CNFR.csv  Saved
# Finished
# Get Data for :  CNK
# ./stocks/CNK.csv  Saved
# Finished
# Get Data for :  CNMD
# ./stocks/CNMD.csv  Saved
# Finished
# Get Data for :  CNNE
# ./stocks/CNNE.csv  Saved
# Finished
# Get Data for :  CNO
# ./stocks/CNO.csv  Saved
# Finished
# Get Data for :  CNOB
# ./stocks/CNOB.csv  Saved
# Finished
# Get Data for :  CNP
# ./stocks/CNP.csv  Saved
# Finished
# Get Data for :  CNS
# ./stocks/CNS.csv  Saved
# Finished
# Get Data for :  CNSL
# ./stocks/CNSL.csv  Saved
# Finished
# Get Data for :  CNTY
# ./stocks/CNTY.csv  Saved
# Finished
# Get Data for :  CNX
# ./stocks/CNX.csv  Saved
# Finished
# Get Data for :  CNXN
# ./stocks/CNXN.csv  Saved
# Finished
# Get Data for :  CODA
# ./stocks/CODA.csv  Saved
# Finished
# Get Data for :  COF
# ./stocks/COF.csv  Saved
# Finished
# Get Data for :  COG
# - COG: No data found, symbol may be delisted
# ./stocks/COG.csv  Saved
# Finished
# Get Data for :  COHN
# ./stocks/COHN.csv  Saved
# Finished
# Get Data for :  COHR
# ./stocks/COHR.csv  Saved
# Finished
# Get Data for :  COHU
# ./stocks/COHU.csv  Saved
# Finished
# Get Data for :  COKE
# ./stocks/COKE.csv  Saved
# Finished
# Get Data for :  COLB
# ./stocks/COLB.csv  Saved
# Finished
# Get Data for :  COLD
# ./stocks/COLD.csv  Saved
# Finished
# Get Data for :  COLL
# ./stocks/COLL.csv  Saved
# Finished
# Get Data for :  COLM
# ./stocks/COLM.csv  Saved
# Finished
# Get Data for :  COMM
# ./stocks/COMM.csv  Saved
# Finished
# Get Data for :  CONE
# ./stocks/CONE.csv  Saved
# Finished
# Get Data for :  CONN
# ./stocks/CONN.csv  Saved
# Finished
# Get Data for :  COO
# ./stocks/COO.csv  Saved
# Finished
# Get Data for :  COOP
# ./stocks/COOP.csv  Saved
# Finished
# Get Data for :  COP
# ./stocks/COP.csv  Saved
# Finished
# Get Data for :  COR
# ./stocks/COR.csv  Saved
# Finished
# Get Data for :  CORE
# - CORE: No data found, symbol may be delisted
# ./stocks/CORE.csv  Saved
# Finished
# Get Data for :  CORR
# ./stocks/CORR.csv  Saved
# Finished
# Get Data for :  CORT
# ./stocks/CORT.csv  Saved
# Finished
# Get Data for :  COST
# ./stocks/COST.csv  Saved
# Finished
# Get Data for :  COTY
# ./stocks/COTY.csv  Saved
# Finished
# Get Data for :  COUP
# ./stocks/COUP.csv  Saved
# Finished
# Get Data for :  COWN
# ./stocks/COWN.csv  Saved
# Finished
# Get Data for :  CPB
# ./stocks/CPB.csv  Saved
# Finished
# Get Data for :  CPE
# ./stocks/CPE.csv  Saved
# Finished
# Get Data for :  CPF
# ./stocks/CPF.csv  Saved
# Finished
# Get Data for :  CPHC
# ./stocks/CPHC.csv  Saved
# Finished
# Get Data for :  CPIX
# ./stocks/CPIX.csv  Saved
# Finished
# Get Data for :  CPK
# ./stocks/CPK.csv  Saved
# Finished
# Get Data for :  CPLG
# ./stocks/CPLG.csv  Saved
# Finished
# Get Data for :  CPRI
# ./stocks/CPRI.csv  Saved
# Finished
# Get Data for :  CPRT
# ./stocks/CPRT.csv  Saved
# Finished
# Get Data for :  CPRX
# ./stocks/CPRX.csv  Saved
# Finished
# Get Data for :  CPS
# ./stocks/CPS.csv  Saved
# Finished
# Get Data for :  CPSH
# ./stocks/CPSH.csv  Saved
# Finished
# Get Data for :  CPSI
# ./stocks/CPSI.csv  Saved
# Finished
# Get Data for :  CPSS
# ./stocks/CPSS.csv  Saved
# Finished
# Get Data for :  CPST
# - CPST: No data found, symbol may be delisted
# ./stocks/CPST.csv  Saved
# Finished
# Get Data for :  CPT
# ./stocks/CPT.csv  Saved
# Finished
# Get Data for :  CR
# ./stocks/CR.csv  Saved
# Finished
# Get Data for :  CRAI
# ./stocks/CRAI.csv  Saved
# Finished
# Get Data for :  CRBP
# ./stocks/CRBP.csv  Saved
# Finished
# Get Data for :  CRC
# ./stocks/CRC.csv  Saved
# Finished
# Get Data for :  CREE
# - CREE: No data found, symbol may be delisted
# ./stocks/CREE.csv  Saved
# Finished
# Get Data for :  CRI
# ./stocks/CRI.csv  Saved
# Finished
# Get Data for :  CRIS
# ./stocks/CRIS.csv  Saved
# Finished
# Get Data for :  CRK
# ./stocks/CRK.csv  Saved
# Finished
# Get Data for :  CRL
# ./stocks/CRL.csv  Saved
# Finished
# Get Data for :  CRM
# ./stocks/CRM.csv  Saved
# Finished
# Get Data for :  CRMD
# ./stocks/CRMD.csv  Saved
# Finished
# Get Data for :  CRMT
# ./stocks/CRMT.csv  Saved
# Finished
# Get Data for :  CRNX
# ./stocks/CRNX.csv  Saved
# Finished
# Get Data for :  CROX
# ./stocks/CROX.csv  Saved
# Finished
# Get Data for :  CRS
# ./stocks/CRS.csv  Saved
# Finished
# Get Data for :  CRTX
# ./stocks/CRTX.csv  Saved
# Finished
# Get Data for :  CRUS
# ./stocks/CRUS.csv  Saved
# Finished
# Get Data for :  CRVL
# ./stocks/CRVL.csv  Saved
# Finished
# Get Data for :  CRVS
# ./stocks/CRVS.csv  Saved
# Finished
# Get Data for :  CRWS
# ./stocks/CRWS.csv  Saved
# Finished
# Get Data for :  CRY
# ./stocks/CRY.csv  Saved
# Finished
# Get Data for :  CSCO
# ./stocks/CSCO.csv  Saved
# Finished
# Get Data for :  CSGP
# ./stocks/CSGP.csv  Saved
# Finished
# Get Data for :  CSGS
# ./stocks/CSGS.csv  Saved
# Finished
# Get Data for :  CSII
# ./stocks/CSII.csv  Saved
# Finished
# Get Data for :  CSL
# ./stocks/CSL.csv  Saved
# Finished
# Get Data for :  CSLT
# ./stocks/CSLT.csv  Saved
# Finished
# Get Data for :  CSOD
# - CSOD: No data found, symbol may be delisted
# ./stocks/CSOD.csv  Saved
# Finished
# Get Data for :  CSPI
# ./stocks/CSPI.csv  Saved
# Finished
# Get Data for :  CSTR
# ./stocks/CSTR.csv  Saved
# Finished
# Get Data for :  CSU
# ./stocks/CSU.csv  Saved
# Finished
# Get Data for :  CSV
# ./stocks/CSV.csv  Saved
# Finished
# Get Data for :  CSWI
# ./stocks/CSWI.csv  Saved
# Finished
# Get Data for :  CSX
# ./stocks/CSX.csv  Saved
# Finished
# Get Data for :  CTAS
# ./stocks/CTAS.csv  Saved
# Finished
# Get Data for :  CTB
# - CTB: No data found, symbol may be delisted
# ./stocks/CTB.csv  Saved
# Finished
# Get Data for :  CTBI
# ./stocks/CTBI.csv  Saved
# Finished
# Get Data for :  CTG
# ./stocks/CTG.csv  Saved
# Finished
# Get Data for :  CTHR
# ./stocks/CTHR.csv  Saved
# Finished
# Get Data for :  CTIB
# ./stocks/CTIB.csv  Saved
# Finished
# Get Data for :  CTIC
# ./stocks/CTIC.csv  Saved
# Finished
# Get Data for :  CTL
# - CTL: No data found, symbol may be delisted
# ./stocks/CTL.csv  Saved
# Finished
# Get Data for :  CTLT
# ./stocks/CTLT.csv  Saved
# Finished
# Get Data for :  CTMX
# ./stocks/CTMX.csv  Saved
# Finished
# Get Data for :  CTO
# ./stocks/CTO.csv  Saved
# Finished
# Get Data for :  CTRE
# ./stocks/CTRE.csv  Saved
# Finished
# Get Data for :  CTRN
# ./stocks/CTRN.csv  Saved
# Finished
# Get Data for :  CTS
# ./stocks/CTS.csv  Saved
# Finished
# Get Data for :  CTSH
# ./stocks/CTSH.csv  Saved
# Finished
# Get Data for :  CTSO
# ./stocks/CTSO.csv  Saved
# Finished
# Get Data for :  CTT
# ./stocks/CTT.csv  Saved
# Finished
# Get Data for :  CTXS
# ./stocks/CTXS.csv  Saved
# Finished
# Get Data for :  CUB
# - CUB: No data found, symbol may be delisted
# ./stocks/CUB.csv  Saved
# Finished
# Get Data for :  CUBE
# ./stocks/CUBE.csv  Saved
# Finished
# Get Data for :  CUBI
# ./stocks/CUBI.csv  Saved
# Finished
# Get Data for :  CUE
# ./stocks/CUE.csv  Saved
# Finished
# Get Data for :  CULP
# ./stocks/CULP.csv  Saved
# Finished
# Get Data for :  CURO
# ./stocks/CURO.csv  Saved
# Finished
# Get Data for :  CUTR
# ./stocks/CUTR.csv  Saved
# Finished
# Get Data for :  CUZ
# ./stocks/CUZ.csv  Saved
# Finished
# Get Data for :  CVA
# ./stocks/CVA.csv  Saved
# Finished
# Get Data for :  CVBF
# ./stocks/CVBF.csv  Saved
# Finished
# Get Data for :  CVCO
# ./stocks/CVCO.csv  Saved
# Finished
# Get Data for :  CVCY
# ./stocks/CVCY.csv  Saved
# Finished
# Get Data for :  CVGI
# ./stocks/CVGI.csv  Saved
# Finished
# Get Data for :  CVGW
# ./stocks/CVGW.csv  Saved
# Finished
# Get Data for :  CVI
# ./stocks/CVI.csv  Saved
# Finished
# Get Data for :  CVIA
# - CVIA: No data found, symbol may be delisted
# ./stocks/CVIA.csv  Saved
# Finished
# Get Data for :  CVLT
# ./stocks/CVLT.csv  Saved
# Finished
# Get Data for :  CVLY
# ./stocks/CVLY.csv  Saved
# Finished
# Get Data for :  CVM
# ./stocks/CVM.csv  Saved
# Finished
# Get Data for :  CVNA
# ./stocks/CVNA.csv  Saved
# Finished
# Get Data for :  CVR
# ./stocks/CVR.csv  Saved
# Finished
# Get Data for :  CVS
# ./stocks/CVS.csv  Saved
# Finished
# Get Data for :  CVTI
# - CVTI: No data found, symbol may be delisted
# ./stocks/CVTI.csv  Saved
# Finished
# Get Data for :  CVU
# ./stocks/CVU.csv  Saved
# Finished
# Get Data for :  CVV
# ./stocks/CVV.csv  Saved
# Finished
# Get Data for :  CVX
# ./stocks/CVX.csv  Saved
# Finished
# Get Data for :  CW
# ./stocks/CW.csv  Saved
# Finished
# Get Data for :  CWBC
# ./stocks/CWBC.csv  Saved
# Finished
# Get Data for :  CWBR
# ./stocks/CWBR.csv  Saved
# Finished
# Get Data for :  CWEN
# ./stocks/CWEN.csv  Saved
# Finished
# Get Data for :  CWH
# ./stocks/CWH.csv  Saved
# Finished
# Get Data for :  CWST
# ./stocks/CWST.csv  Saved
# Finished
# Get Data for :  CWT
# ./stocks/CWT.csv  Saved
# Finished
# Get Data for :  CXO
# - CXO: No data found, symbol may be delisted
# ./stocks/CXO.csv  Saved
# Finished
# Get Data for :  CXP
# ./stocks/CXP.csv  Saved
# Finished
# Get Data for :  CXW
# ./stocks/CXW.csv  Saved
# Finished
# Get Data for :  CYAN
# ./stocks/CYAN.csv  Saved
# Finished
# Get Data for :  CYBE
# ./stocks/CYBE.csv  Saved
# Finished
# Get Data for :  CYCC
# ./stocks/CYCC.csv  Saved
# Finished
# Get Data for :  CYH
# ./stocks/CYH.csv  Saved
# Finished
# Get Data for :  CYRX
# ./stocks/CYRX.csv  Saved
# Finished
# Get Data for :  CYTK
# ./stocks/CYTK.csv  Saved
# Finished
# Get Data for :  CYTR
# ./stocks/CYTR.csv  Saved
# Finished
# Get Data for :  CZNC
# ./stocks/CZNC.csv  Saved
# Finished
# Get Data for :  CZR
# ./stocks/CZR.csv  Saved
# Finished
# Get Data for :  CZWI
# ./stocks/CZWI.csv  Saved
# Finished
# Get Data for :  D
# ./stocks/D.csv  Saved
# Finished
# Get Data for :  DAIO
# ./stocks/DAIO.csv  Saved
# Finished
# Get Data for :  DAKT
# ./stocks/DAKT.csv  Saved
# Finished
# Get Data for :  DAL
# ./stocks/DAL.csv  Saved
# Finished
# Get Data for :  DAN
# ./stocks/DAN.csv  Saved
# Finished
# Get Data for :  DAR
# ./stocks/DAR.csv  Saved
# Finished
# Get Data for :  DARE
# ./stocks/DARE.csv  Saved
# Finished
# Get Data for :  DBD
# ./stocks/DBD.csv  Saved
# Finished
# Get Data for :  DBI
# ./stocks/DBI.csv  Saved
# Finished
# Get Data for :  DBX
# ./stocks/DBX.csv  Saved
# Finished
# Get Data for :  DCI
# ./stocks/DCI.csv  Saved
# Finished
# Get Data for :  DCO
# ./stocks/DCO.csv  Saved
# Finished
# Get Data for :  DCOM
# ./stocks/DCOM.csv  Saved
# Finished
# Get Data for :  DCPH
# ./stocks/DCPH.csv  Saved
# Finished
# Get Data for :  DD
# ./stocks/DD.csv  Saved
# Finished
# Get Data for :  DDD
# ./stocks/DDD.csv  Saved
# Finished
# Get Data for :  DDS
# ./stocks/DDS.csv  Saved
# Finished
# Get Data for :  DE
# ./stocks/DE.csv  Saved
# Finished
# Get Data for :  DEA
# ./stocks/DEA.csv  Saved
# Finished
# Get Data for :  DECK
# ./stocks/DECK.csv  Saved
# Finished
# Get Data for :  DEI
# ./stocks/DEI.csv  Saved
# Finished
# Get Data for :  DELL
# ./stocks/DELL.csv  Saved
# Finished
# ...
# ./stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# ./stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# ./stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YMAB
# ./stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# ./stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# ./stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YTEN
# ./stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YUM
# ./stocks/YUM.csv  Saved
# Finished
# Get Data for :  Z
# ./stocks/Z.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# ./stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZBH
# ./stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZBRA
# ./stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# ./stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# ./stocks/ZEN.csv  Saved
# Finished
# Get Data for :  ZEUS
# ./stocks/ZEUS.csv  Saved
# Finished
# Get Data for :  ZG
# ./stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZGNX
# ./stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZION
# ./stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# ./stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# ./stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZM
# ./stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# ./stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZNGA
# ./stocks/ZNGA.csv  Saved
# Finished
# Get Data for :  ZS
# ./stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZSAN
# ./stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZTS
# ./stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# ./stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# ./stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# ./stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  UONEK
# ./stocks/UONEK.csv  Saved
# Finished
# Get Data for :  URBN
# ./stocks/URBN.csv  Saved
# Finished
# Get Data for :  UROV
# - UROV: No data found, symbol may be delisted
# ./stocks/UROV.csv  Saved
# Finished
# Get Data for :  UBA
# ./stocks/UBA.csv  Saved
# Finished
# Get Data for :  ECOL
# ./stocks/ECOL.csv  Saved
# Finished
# Get Data for :  USEG
# ./stocks/USEG.csv  Saved
# Finished
# Get Data for :  USFD
# ./stocks/USFD.csv  Saved
# Finished
# Get Data for :  USWS
# ./stocks/USWS.csv  Saved
# Finished
# Get Data for :  USX
# ./stocks/USX.csv  Saved
# Finished
# Get Data for :  USAT
# - USAT: No data found, symbol may be delisted
# ./stocks/USAT.csv  Saved
# Finished
# Get Data for :  USAK
# ./stocks/USAK.csv  Saved
# Finished
# Get Data for :  USNA
# ./stocks/USNA.csv  Saved
# Finished
# Get Data for :  USIO
# ./stocks/USIO.csv  Saved
# Finished
# Get Data for :  UTMD
# ./stocks/UTMD.csv  Saved
# Finished
# Get Data for :  EGY
# ./stocks/EGY.csv  Saved
# Finished
# Get Data for :  MTN
# ./stocks/MTN.csv  Saved
# Finished
# Get Data for :  VAL
# ./stocks/VAL.csv  Saved
# Finished
# Get Data for :  VLO
# ./stocks/VLO.csv  Saved
# Finished
# Get Data for :  VLY
# ./stocks/VLY.csv  Saved
# Finished
# Get Data for :  VMI
# ./stocks/VMI.csv  Saved
# Finished
# Get Data for :  VALU
# ./stocks/VALU.csv  Saved
# Finished
# Get Data for :  VVV
# ./stocks/VVV.csv  Saved
# Finished
# Get Data for :  VNDA
# ./stocks/VNDA.csv  Saved
# Finished
# Get Data for :  VAPO
# ./stocks/VAPO.csv  Saved
# Finished
# Get Data for :  VREX
# ./stocks/VREX.csv  Saved
# Finished
# Get Data for :  VAR
# - VAR: No data found, symbol may be delisted
# ./stocks/VAR.csv  Saved
# Finished
# Get Data for :  VRNS
# ./stocks/VRNS.csv  Saved
# Finished
# Get Data for :  VXRT
# ./stocks/VXRT.csv  Saved
# Finished
# Get Data for :  VBIV
# ./stocks/VBIV.csv  Saved
# Finished
# Get Data for :  VGR
# ./stocks/VGR.csv  Saved
# Finished
# Get Data for :  VEC
# ./stocks/VEC.csv  Saved
# Finished
# Get Data for :  VECO
# ./stocks/VECO.csv  Saved
# Finished
# Get Data for :  VEEV
# ./stocks/VEEV.csv  Saved
# Finished
# Get Data for :  VNTR
# ./stocks/VNTR.csv  Saved
# Finished
# Get Data for :  VTR
# ./stocks/VTR.csv  Saved
# Finished
# Get Data for :  VNE
# ./stocks/VNE.csv  Saved
# Finished
# Get Data for :  VRA
# ./stocks/VRA.csv  Saved
# Finished
# Get Data for :  VCYT
# ./stocks/VCYT.csv  Saved
# Finished
# Get Data for :  VSTM
# ./stocks/VSTM.csv  Saved
# Finished
# Get Data for :  VER
# - VER: No data found, symbol may be delisted
# ./stocks/VER.csv  Saved
# Finished
# Get Data for :  VCEL
# ./stocks/VCEL.csv  Saved
# Finished
# Get Data for :  VRNT
# ./stocks/VRNT.csv  Saved
# Finished
# Get Data for :  VRSN
# ./stocks/VRSN.csv  Saved
# Finished
# Get Data for :  VRSK
# ./stocks/VRSK.csv  Saved
# Finished
# Get Data for :  VBTX
# ./stocks/VBTX.csv  Saved
# Finished
# Get Data for :  VRTV
# ./stocks/VRTV.csv  Saved
# Finished
# Get Data for :  VERI
# ./stocks/VERI.csv  Saved
# Finished
# Get Data for :  VZ
# ./stocks/VZ.csv  Saved
# Finished
# Get Data for :  VRML
# - VRML: No data found, symbol may be delisted
# ./stocks/VRML.csv  Saved
# Finished
# Get Data for :  VRRM
# ./stocks/VRRM.csv  Saved
# Finished
# Get Data for :  VRS
# ./stocks/VRS.csv  Saved
# Finished
# Get Data for :  VTNR
# ./stocks/VTNR.csv  Saved
# Finished
# Get Data for :  VRTX
# ./stocks/VRTX.csv  Saved
# Finished
# Get Data for :  VERU
# ./stocks/VERU.csv  Saved
# Finished
# Get Data for :  VFC
# ./stocks/VFC.csv  Saved
# Finished
# Get Data for :  CBS
# - CBS: No data found, symbol may be delisted
# ./stocks/CBS.csv  Saved
# Finished
# Get Data for :  VVI
# ./stocks/VVI.csv  Saved
# Finished
# Get Data for :  VSAT
# ./stocks/VSAT.csv  Saved
# Finished
# Get Data for :  VIAV
# ./stocks/VIAV.csv  Saved
# Finished
# Get Data for :  VICL
# - VICL: No data found, symbol may be delisted
# ./stocks/VICL.csv  Saved
# Finished
# Get Data for :  VICI
# ./stocks/VICI.csv  Saved
# Finished
# Get Data for :  VICR
# ./stocks/VICR.csv  Saved
# Finished
# Get Data for :  VCTR
# ./stocks/VCTR.csv  Saved
# Finished
# Get Data for :  VRAY
# ./stocks/VRAY.csv  Saved
# Finished
# Get Data for :  VKTX
# ./stocks/VKTX.csv  Saved
# Finished
# Get Data for :  VBFC
# ./stocks/VBFC.csv  Saved
# Finished
# Get Data for :  VLGEA
# ./stocks/VLGEA.csv  Saved
# Finished
# Get Data for :  VNCE
# ./stocks/VNCE.csv  Saved
# Finished
# Get Data for :  VIRC
# ./stocks/VIRC.csv  Saved
# Finished
# Get Data for :  VHC
# ./stocks/VHC.csv  Saved
# Finished
# Get Data for :  VIRT
# ./stocks/VIRT.csv  Saved
# Finished
# Get Data for :  VRTS
# ./stocks/VRTS.csv  Saved
# Finished
# Get Data for :  VRTU
# - VRTU: No data found, symbol may be delisted
# ./stocks/VRTU.csv  Saved
# Finished
# Get Data for :  V
# ./stocks/V.csv  Saved
# Finished
# Get Data for :  VSH
# ./stocks/VSH.csv  Saved
# Finished
# Get Data for :  VPG
# ./stocks/VPG.csv  Saved
# Finished
# Get Data for :  VISL
# ./stocks/VISL.csv  Saved
# Finished
# Get Data for :  VSTO
# ./stocks/VSTO.csv  Saved
# Finished
# Get Data for :  VC
# ./stocks/VC.csv  Saved
# Finished
# Get Data for :  VST
# ./stocks/VST.csv  Saved
# Finished
# Get Data for :  VSI
# - VSI: No data found, symbol may be delisted
# ./stocks/VSI.csv  Saved
# Finished
# Get Data for :  VSLR
# - VSLR: No data found, symbol may be delisted
# ./stocks/VSLR.csv  Saved
# Finished
# Get Data for :  VVUS
# - VVUS: No data found, symbol may be delisted
# ./stocks/VVUS.csv  Saved
# Finished
# Get Data for :  VMW
# ./stocks/VMW.csv  Saved
# Finished
# Get Data for :  VCRA
# ./stocks/VCRA.csv  Saved
# Finished
# Get Data for :  VNRX
# ./stocks/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# ./stocks/VISI.csv  Saved
# Finished
# Get Data for :  VG
# ./stocks/VG.csv  Saved
# Finished
# Get Data for :  VNO
# ./stocks/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# ./stocks/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# ./stocks/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# ./stocks/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# ./stocks/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# ./stocks/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# ./stocks/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# ./stocks/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# ./stocks/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# ./stocks/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# ./stocks/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# ./stocks/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# ./stocks/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# ./stocks/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# ./stocks/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# ./stocks/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# ./stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# ./stocks/WBA.csv  Saved
# Finished
# Get Data for :  WD
# ./stocks/WD.csv  Saved
# Finished
# Get Data for :  WMT
# ./stocks/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# ./stocks/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# ./stocks/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# ./stocks/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# ./stocks/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# ./stocks/WASH.csv  Saved
# Finished
# Get Data for :  WM
# ./stocks/WM.csv  Saved
# Finished
# Get Data for :  WAT
# ./stocks/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# ./stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# ./stocks/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# ./stocks/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# ./stocks/WVE.csv  Saved
# Finished
# Get Data for :  W
# ./stocks/W.csv  Saved
# Finished
# Get Data for :  WSTG
# ./stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# ./stocks/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# ./stocks/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# ./stocks/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# ./stocks/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# ./stocks/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# ./stocks/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# ./stocks/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# ./stocks/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# ./stocks/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# ./stocks/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# ./stocks/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# ./stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# ./stocks/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# ./stocks/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# ./stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# ./stocks/WST.csv  Saved
# Finished
# Get Data for :  WABC
# ./stocks/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# ./stocks/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# ./stocks/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# ./stocks/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# ./stocks/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# ./stocks/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# ./stocks/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# ./stocks/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# ./stocks/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# ./stocks/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# ./stocks/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# ./stocks/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# ./stocks/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# ./stocks/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# ./stocks/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# ./stocks/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# ./stocks/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# ./stocks/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# ./stocks/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# ./stocks/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# ./stocks/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# ./stocks/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# ./stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# ./stocks/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# ./stocks/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# ./stocks/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# ./stocks/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# ./stocks/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# ./stocks/WSC.csv  Saved
# Finished
# Get Data for :  WING
# ./stocks/WING.csv  Saved
# Finished
# Get Data for :  WINA
# ./stocks/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# ./stocks/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# ./stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# ./stocks/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# ./stocks/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# ./stocks/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# ./stocks/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# ./stocks/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# ./stocks/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# ./stocks/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# ./stocks/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# ./stocks/INT.csv  Saved
# Finished
# Get Data for :  WWE
# ./stocks/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# ./stocks/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# ./stocks/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# ./stocks/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# ./stocks/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# ./stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# ./stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# ./stocks/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# ./stocks/WYND.csv  Saved
# Finished
# Get Data for :  WH
# ./stocks/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# ./stocks/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# ./stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# ./stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# ./stocks/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# ./stocks/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# ./stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# ./stocks/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# ./stocks/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# ./stocks/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# ./stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# ./stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# ./stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# ./stocks/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# ./stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# ./stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# ./stocks/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# ./stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# ./stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# ./stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# ./stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# ./stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# ./stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# ./stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# ./stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# ./stocks/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# ./stocks/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# ./stocks/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# ./stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# ./stocks/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# ./stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# ./stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# ./stocks/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# ./stocks/Z.csv  Saved
# Finished
# Get Data for :  ZG
# ./stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# ./stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# ./stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# ./stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# ./stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# ./stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# ./stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# ./stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# ./stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# ./stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# ./stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# ./stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# ./stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# ./stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# ./stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# ./stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# ./stocks/ZNGA.csv  Saved
# Finished
